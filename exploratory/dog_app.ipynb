# %% [markdown]
# # Data Scientist Nanodegree
#
# ## Convolutional Neural Networks
#
# ## Project: Write an Algorithm for a Dog Identification App
#
#
# This notebook walks you through one of the most popular Udacity projects across machine learning and artificial intellegence nanodegree programs.  The goal is to classify images of dogs according to their breed.
#
# If you are looking for a more guided capstone project related to deep learning and convolutional neural networks, this might be just it.  Notice that even if you follow the notebook to creating your classifier, you must still create a blog post or deploy an application to fulfill the requirements of the capstone project.
#
# Also notice, you may be able to use only parts of this notebook (for example certain coding portions or the data) without completing all parts and still meet all requirements of the capstone project.
#
# ---
#
# In this notebook, some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this project. You will not need to modify the included code beyond what is requested. Sections that begin with **'(IMPLEMENTATION)'** in the header indicate that the following block of code will require additional functionality which you must provide. Instructions will be provided for each section, and the specifics of the implementation are marked in the code block with a 'TODO' statement. Please be sure to read the instructions carefully!
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question X'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut.  Markdown cells can be edited by double-clicking the cell to enter edit mode.
#
# The rubric contains _optional_ "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. If you decide to pursue the "Stand Out Suggestions", you should include the code in this IPython notebook.
#
#
#
# ---
# ### Why We're Here
#
# In this notebook, you will make the first steps towards developing an algorithm that could be used as part of a mobile or web app.  At the end of this project, your code will accept any user-supplied image as input.  If a dog is detected in the image, it will provide an estimate of the dog's breed.  If a human is detected, it will provide an estimate of the dog breed that is most resembling.  The image below displays potential sample output of your finished project (... but we expect that each student's algorithm will behave differently!).
#
# ![Sample Dog Output](images/sample_dog_output.png)
#
# In this real-world setting, you will need to piece together a series of models to perform different tasks; for instance, the algorithm that detects humans in an image will be different from the CNN that infers dog breed.  There are many points of possible failure, and no perfect algorithm exists.  Your imperfect solution will nonetheless create a fun user experience!
#
# ### The Road Ahead
#
# We break the notebook into separate steps.  Feel free to use the links below to navigate the notebook.
#
# * [Step 0](#step0): Import Datasets
# * [Step 1](#step1): Detect Humans
# * [Step 2](#step2): Detect Dogs
# * [Step 3](#step3): Create a CNN to Classify Dog Breeds (from Scratch)
# * [Step 4](#step4): Use a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 5](#step5): Create a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 6](#step6): Write your Algorithm
# * [Step 7](#step7): Test Your Algorithm
#
# ---
# <a id='step0'></a>
# ## Step 0: Import Datasets
#
# ### Import Dog Dataset
#
# In the code cell below, we import a dataset of dog images.  We populate a few variables through the use of the `load_files` function from the scikit-learn library:
# - `train_files`, `valid_files`, `test_files` - numpy arrays containing file paths to images
# - `train_targets`, `valid_targets`, `test_targets` - numpy arrays containing onehot-encoded classification labels
# - `dog_names` - list of string-valued dog breed names for translating labels

# %%
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
from glob import glob

# define function to load train, test, and validation datasets
def load_dataset(path):
    data = load_files(path)
    dog_files = np.array(data['filenames'])
    dog_targets = np_utils.to_categorical(np.array(data['target']), 133)
    return dog_files, dog_targets

# load train, test, and validation datasets
train_files, train_targets = load_dataset('../../../data/dog_images/train')
valid_files, valid_targets = load_dataset('../../../data/dog_images/valid')
test_files, test_targets = load_dataset('../../../data/dog_images/test')

# load list of dog names
dog_names = [item[20:-1] for item in sorted(glob("../../../data/dog_images/train/*/"))]

# print statistics about the dataset
print('There are %d total dog categories.' % len(dog_names))
print('There are %s total dog images.\n' % len(np.hstack([train_files, valid_files, test_files])))
print('There are %d training dog images.' % len(train_files))
print('There are %d validation dog images.' % len(valid_files))
print('There are %d test dog images.'% len(test_files))
# Out:
# There are 133 total dog categories.
# There are 8351 total dog images.
#
# There are 6680 training dog images.
# There are 835 validation dog images.
# There are 836 test dog images.
#  28%|██▊       | 1851/6680 [00:39<01:42, 47.18it/s]

# %% [markdown]
# ### Import Human Dataset
#
# In the code cell below, we import a dataset of human images, where the file paths are stored in the numpy array `human_files`.

# %%
import random
random.seed(8675309)

# load filenames in shuffled human dataset
human_files = np.array(glob("../../../data/lfw/*/*"))
random.shuffle(human_files)

# print statistics about the dataset
print('There are %d total human images.' % len(human_files))
# Out:
# There are 13233 total human images.

# %% [markdown]
# ---
# <a id='step1'></a>
# ## Step 1: Detect Humans
#
# We use OpenCV's implementation of [Haar feature-based cascade classifiers](http://docs.opencv.org/trunk/d7/d8b/tutorial_py_face_detection.html) to detect human faces in images.  OpenCV provides many pre-trained face detectors, stored as XML files on [github](https://github.com/opencv/opencv/tree/master/data/haarcascades).  We have downloaded one of these detectors and stored it in the `haarcascades` directory.
#
# In the next code cell, we demonstrate how to use this detector to find human faces in a sample image.

# %%
import cv2                
import matplotlib.pyplot as plt                        
# %matplotlib inline                               

# extract pre-trained face detector
face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')

# load color (BGR) image
img = cv2.imread(human_files[3])
# convert BGR image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# find faces in image
faces = face_cascade.detectMultiScale(gray)

# print number of faces detected in the image
print('Number of faces detected:', len(faces))

# get bounding box for each detected face
for (x,y,w,h) in faces:
    # add bounding box to color image
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    
# convert BGR image to RGB for plotting
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# display the image, along with bounding box
plt.imshow(cv_rgb)
plt.show()
# Out:
# Number of faces detected: 1

# %% [markdown]
# Before using any of the face detectors, it is standard procedure to convert the images to grayscale.  The `detectMultiScale` function executes the classifier stored in `face_cascade` and takes the grayscale image as a parameter.
#
# In the above code, `faces` is a numpy array of detected faces, where each row corresponds to a detected face.  Each detected face is a 1D array with four entries that specifies the bounding box of the detected face.  The first two entries in the array (extracted in the above code as `x` and `y`) specify the horizontal and vertical positions of the top left corner of the bounding box.  The last two entries in the array (extracted here as `w` and `h`) specify the width and height of the box.
#
# ### Write a Human Face Detector
#
# We can use this procedure to write a function that returns `True` if a human face is detected in an image and `False` otherwise.  This function, aptly named `face_detector`, takes a string-valued file path to an image as input and appears in the code block below.

# %%
# returns "True" if face is detected in image stored at img_path
def face_detector(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    return len(faces) > 0

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Human Face Detector
#
# __Question 1:__ Use the code cell below to test the performance of the `face_detector` function.
# - What percentage of the first 100 images in `human_files` have a detected human face?
# - What percentage of the first 100 images in `dog_files` have a detected human face?
#
# Ideally, we would like 100% of human images with a detected face and 0% of dog images with a detected face.  You will see that our algorithm falls short of this goal, but still gives acceptable performance.  We extract the file paths for the first 100 images from each of the datasets and store them in the numpy arrays `human_files_short` and `dog_files_short`.
#
# __Answer:__

# %%
human_files_short = human_files[:100]
dog_files_short = train_files[:100]
# Do NOT modify the code above this line.

## TODO: Test the performance of the face_detector algorithm 
pred_human = []
for img in human_files_short:
    pred_human.append(face_detector(img))
pred_dog = []
for img in dog_files_short:
    pred_dog.append(face_detector(img))
print(np.sum(pred_human), np.sum(pred_dog))
## on the images in human_files_short and dog_files_short.
# Out:
# 100 11

# %% [markdown]
# __Question 2:__ This algorithmic choice necessitates that we communicate to the user that we accept human images only when they provide a clear view of a face (otherwise, we risk having unneccessarily frustrated users!). In your opinion, is this a reasonable expectation to pose on the user? If not, can you think of a way to detect humans in images that does not necessitate an image with a clearly presented face?
#
# __Answer:__
#
# We suggest the face detector from OpenCV as a potential way to detect human images in your algorithm, but you are free to explore other approaches, especially approaches that make use of deep learning :).  Please use the code cell below to design and test your own face detection algorithm.  If you decide to pursue this _optional_ task, report performance on each of the datasets.

# %%
## (Optional) TODO: Report the performance of another  
## face detection algorithm on the LFW dataset
### Feel free to use as many code cells as needed.

# %% [markdown]
# ---
# <a id='step2'></a>
# ## Step 2: Detect Dogs
#
# In this section, we use a pre-trained [ResNet-50](http://ethereon.github.io/netscope/#/gist/db945b393d40bfa26006) model to detect dogs in images.  Our first line of code downloads the ResNet-50 model, along with weights that have been trained on [ImageNet](http://www.image-net.org/), a very large, very popular dataset used for image classification and other vision tasks.  ImageNet contains over 10 million URLs, each linking to an image containing an object from one of [1000 categories](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).  Given an image, this pre-trained ResNet-50 model returns a prediction (derived from the available categories in ImageNet) for the object that is contained in the image.

# %%
from keras.applications.resnet50 import ResNet50

# define ResNet50 model
ResNet50_model = ResNet50(weights='imagenet')

# %% [markdown]
# ### Pre-process the Data
#
# When using TensorFlow as backend, Keras CNNs require a 4D array (which we'll also refer to as a 4D tensor) as input, with shape
#
# $$
# (\text{nb_samples}, \text{rows}, \text{columns}, \text{channels}),
# $$
#
# where `nb_samples` corresponds to the total number of images (or samples), and `rows`, `columns`, and `channels` correspond to the number of rows, columns, and channels for each image, respectively.
#
# The `path_to_tensor` function below takes a string-valued file path to a color image as input and returns a 4D tensor suitable for supplying to a Keras CNN.  The function first loads the image and resizes it to a square image that is $224 \times 224$ pixels.  Next, the image is converted to an array, which is then resized to a 4D tensor.  In this case, since we are working with color images, each image has three channels.  Likewise, since we are processing a single image (or sample), the returned tensor will always have shape
#
# $$
# (1, 224, 224, 3).
# $$
#
# The `paths_to_tensor` function takes a numpy array of string-valued image paths as input and returns a 4D tensor with shape
#
# $$
# (\text{nb_samples}, 224, 224, 3).
# $$
#
# Here, `nb_samples` is the number of samples, or number of images, in the supplied array of image paths.  It is best to think of `nb_samples` as the number of 3D tensors (where each 3D tensor corresponds to a different image) in your dataset!

# %%
from keras.preprocessing import image                  
from tqdm import tqdm

def path_to_tensor(img_path):
    # loads RGB image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=(224, 224))
    # convert PIL.Image.Image type to 3D tensor with shape (224, 224, 3)
    x = image.img_to_array(img)
    # convert 3D tensor to 4D tensor with shape (1, 224, 224, 3) and return 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %% [markdown]
# ### Making Predictions with ResNet-50
#
# Getting the 4D tensor ready for ResNet-50, and for any other pre-trained model in Keras, requires some additional processing.  First, the RGB image is converted to BGR by reordering the channels.  All pre-trained models have the additional normalization step that the mean pixel (expressed in RGB as $[103.939, 116.779, 123.68]$ and calculated from all pixels in all images in ImageNet) must be subtracted from every pixel in each image.  This is implemented in the imported function `preprocess_input`.  If you're curious, you can check the code for `preprocess_input` [here](https://github.com/fchollet/keras/blob/master/keras/applications/imagenet_utils.py).
#
# Now that we have a way to format our image for supplying to ResNet-50, we are now ready to use the model to extract the predictions.  This is accomplished with the `predict` method, which returns an array whose $i$-th entry is the model's predicted probability that the image belongs to the $i$-th ImageNet category.  This is implemented in the `ResNet50_predict_labels` function below.
#
# By taking the argmax of the predicted probability vector, we obtain an integer corresponding to the model's predicted object class, which we can identify with an object category through the use of this [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).

# %%
from keras.applications.resnet50 import preprocess_input, decode_predictions

def ResNet50_predict_labels(img_path):
    # returns prediction vector for image located at img_path
    img = preprocess_input(path_to_tensor(img_path))
    return np.argmax(ResNet50_model.predict(img))

# %% [markdown]
# ### Write a Dog Detector
#
# While looking at the [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a), you will notice that the categories corresponding to dogs appear in an uninterrupted sequence and correspond to dictionary keys 151-268, inclusive, to include all categories from `'Chihuahua'` to `'Mexican hairless'`.  Thus, in order to check to see if an image is predicted to contain a dog by the pre-trained ResNet-50 model, we need only check if the `ResNet50_predict_labels` function above returns a value between 151 and 268 (inclusive).
#
# We use these ideas to complete the `dog_detector` function below, which returns `True` if a dog is detected in an image (and `False` if not).

# %%
### returns "True" if a dog is detected in the image stored at img_path
def dog_detector(img_path):
    prediction = ResNet50_predict_labels(img_path)
    return ((prediction <= 268) & (prediction >= 151))

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Dog Detector
#
# __Question 3:__ Use the code cell below to test the performance of your `dog_detector` function.
# - What percentage of the images in `human_files_short` have a detected dog?
# - What percentage of the images in `dog_files_short` have a detected dog?
#
# __Answer:__

# %%
### TODO: Test the performance of the dog_detector function
### on the images in human_files_short and dog_files_short.
pred_human = []
for img in human_files_short:
    pred_human.append(dog_detector(img))
pred_dog = []
for img in dog_files_short:
    pred_dog.append(dog_detector(img))
print(np.sum(pred_human), np.sum(pred_dog))
# Out:
# 0 100

# %% [markdown]
# ---
# <a id='step3'></a>
# ## Step 3: Create a CNN to Classify Dog Breeds (from Scratch)
#
# Now that we have functions for detecting humans and dogs in images, we need a way to predict breed from images.  In this step, you will create a CNN that classifies dog breeds.  You must create your CNN _from scratch_ (so, you can't use transfer learning _yet_!), and you must attain a test accuracy of at least 1%.  In Step 5 of this notebook, you will have the opportunity to use transfer learning to create a CNN that attains greatly improved accuracy.
#
# Be careful with adding too many trainable layers!  More parameters means longer training, which means you are more likely to need a GPU to accelerate the training process.  Thankfully, Keras provides a handy estimate of the time that each epoch is likely to take; you can extrapolate this estimate to figure out how long it will take for your algorithm to train.
#
# We mention that the task of assigning breed to dogs from images is considered exceptionally challenging.  To see why, consider that *even a human* would have great difficulty in distinguishing between a Brittany and a Welsh Springer Spaniel.
#
# Brittany | Welsh Springer Spaniel
# - | -
# <img src="images/Brittany_02625.jpg" width="100"> | <img src="images/Welsh_springer_spaniel_08203.jpg" width="200">
#
# It is not difficult to find other dog breed pairs with minimal inter-class variation (for instance, Curly-Coated Retrievers and American Water Spaniels).
#
# Curly-Coated Retriever | American Water Spaniel
# - | -
# <img src="images/Curly-coated_retriever_03896.jpg" width="200"> | <img src="images/American_water_spaniel_00648.jpg" width="200">
#
#
# Likewise, recall that labradors come in yellow, chocolate, and black.  Your vision-based algorithm will have to conquer this high intra-class variation to determine how to classify all of these different shades as the same breed.
#
# Yellow Labrador | Chocolate Labrador | Black Labrador
# - | -
# <img src="images/Labrador_retriever_06457.jpg" width="150"> | <img src="images/Labrador_retriever_06455.jpg" width="240"> | <img src="images/Labrador_retriever_06449.jpg" width="220">
#
# We also mention that random chance presents an exceptionally low bar: setting aside the fact that the classes are slightly imabalanced, a random guess will provide a correct answer roughly 1 in 133 times, which corresponds to an accuracy of less than 1%.
#
# Remember that the practice is far ahead of the theory in deep learning.  Experiment with many different architectures, and trust your intuition.  And, of course, have fun!
#
# ### Pre-process the Data
#
# We rescale the images by dividing every pixel in every image by 255.

# %%
from PIL import ImageFile                            
ImageFile.LOAD_TRUNCATED_IMAGES = True                 

# pre-process the data for Keras
train_tensors = paths_to_tensor(train_files).astype('float32')/255
valid_tensors = paths_to_tensor(valid_files).astype('float32')/255
test_tensors = paths_to_tensor(test_files).astype('float32')/255
# Out:
# 100%|██████████| 6680/6680 [01:13<00:00, 90.27it/s]
# 100%|██████████| 835/835 [00:08<00:00, 101.79it/s]
# 100%|██████████| 836/836 [00:08<00:00, 102.92it/s]

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  At the end of your code cell block, summarize the layers of your model by executing the line:
#
#         model.summary()
#
# We have imported some Python modules to get you started, but feel free to import as many modules as you need.  If you end up getting stuck, here's a hint that specifies a model that trains relatively fast on CPU and attains >1% test accuracy in 5 epochs:
#
# ![Sample CNN](images/sample_cnn.png)
#
# __Question 4:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  If you chose to use the hinted architecture above, describe why you think that CNN architecture should work well for the image classification task.
#
# __Answer:__

# %%
train_tensors.shape
# Out:
# (6680, 224, 224, 3)

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential

model = Sequential()

### TODO: Define your architecture.
model.add(Conv2D(filters=16, kernel_size=3, padding='same', activation='relu', input_shape=(224, 224, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))
model.add(Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(GlobalAveragePooling2D())
#model.add(Dense(500, activation='relu'))
model.add(Dense(133, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_25 (Conv2D)           (None, 224, 224, 16)      448
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 112, 112, 16)      0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 112, 112, 32)      4640
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 56, 56, 32)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 56, 56, 64)        18496
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 28, 28, 64)        0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 64)                0
# _________________________________________________________________
# dense_17 (Dense)             (None, 133)               8645
# =================================================================
# Total params: 32,229
# Trainable params: 32,229
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile the Model

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### (IMPLEMENTATION) Train the Model
#
# Train your model in the code cell below.  Use model checkpointing to save the model that attains the best validation loss.
#
# You are welcome to [augment the training data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), but this is not a requirement.

# %%
from keras.callbacks import ModelCheckpoint  

### TODO: specify the number of epochs that you would like to use to train the model.

epochs = 20

### Do NOT modify the code below this line.

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.from_scratch.hdf5', 
                               verbose=1, save_best_only=True)

model.fit(train_tensors, train_targets, 
          validation_data=(valid_tensors, valid_targets),
          epochs=epochs, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.8804 - acc: 0.0111Epoch 00001: val_loss improved from inf to 4.85403, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 24s 4ms/step - loss: 4.8805 - acc: 0.0111 - val_loss: 4.8540 - val_acc: 0.0144
# Epoch 2/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.8301 - acc: 0.0162Epoch 00002: val_loss improved from 4.85403 to 4.81537, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 23s 3ms/step - loss: 4.8304 - acc: 0.0162 - val_loss: 4.8154 - val_acc: 0.0216
# Epoch 3/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.7910 - acc: 0.0191- E - ETA: 5s -  - ETA: 3s - loss: 4.7923  -Epoch 00003: val_loss improved from 4.81537 to 4.78116, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 23s 3ms/step - loss: 4.7911 - acc: 0.0190 - val_loss: 4.7812 - val_acc: 0.0204
# Epoch 4/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.7570 - acc: 0.0204Epoch 00004: val_loss improved from 4.78116 to 4.76272, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 23s 3ms/step - loss: 4.7572 - acc: 0.0205 - val_loss: 4.7627 - val_acc: 0.0251
# Epoch 5/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.7278 - acc: 0.0231Epoch 00005: val_loss did not improve
# 6680/6680 [==============================] - 23s 3ms/step - loss: 4.7268 - acc: 0.0232 - val_loss: 4.8049 - val_acc: 0.0240
# Epoch 6/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.6935 - acc: 0.0258- ETA: 1s - loss: 4.6Epoch 00006: val_loss improved from 4.76272 to 4.72814, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 23s 4ms/step - loss: 4.6942 - acc: 0.0260 - val_loss: 4.7281 - val_acc: 0.0335
# Epoch 7/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.6631 - acc: 0.0348Epoch 00007: val_loss improved from 4.72814 to 4.68904, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 23s 3ms/step - loss: 4.6629 - acc: 0.0349 - val_loss: 4.6890 - val_acc: 0.0323
# Epoch 8/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.6259 - acc: 0.0342Epoch 00008: val_loss improved from 4.68904 to 4.65902, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 23s 3ms/step - loss: 4.6266 - acc: 0.0341 - val_loss: 4.6590 - val_acc: 0.0311
# Epoch 9/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.5847 - acc: 0.0440Epoch 00009: val_loss improved from 4.65902 to 4.65387, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 23s 3ms/step - loss: 4.5852 - acc: 0.0440 - val_loss: 4.6539 - val_acc: 0.0371
# Epoch 10/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.5434 - acc: 0.0489Epoch 00010: val_loss improved from 4.65387 to 4.59291, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 23s 3ms/step - loss: 4.5434 - acc: 0.0488 - val_loss: 4.5929 - val_acc: 0.0407
# Epoch 11/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.5034 - acc: 0.0440- ETA: 0s - loss: 4.5019 - acc:Epoch 00011: val_loss improved from 4.59291 to 4.56441, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 23s 3ms/step - loss: 4.5030 - acc: 0.0439 - val_loss: 4.5644 - val_acc: 0.0395
# Epoch 12/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.4619 - acc: 0.0547Epoch 00012: val_loss improved from 4.56441 to 4.54227, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 23s 3ms/step - loss: 4.4624 - acc: 0.0546 - val_loss: 4.5423 - val_acc: 0.0455
# Epoch 13/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.4249 - acc: 0.0584Epoch 00013: val_loss improved from 4.54227 to 4.53812, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 23s 3ms/step - loss: 4.4246 - acc: 0.0584 - val_loss: 4.5381 - val_acc: 0.0527
# Epoch 14/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.3892 - acc: 0.0610Epoch 00014: val_loss improved from 4.53812 to 4.47818, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 23s 3ms/step - loss: 4.3899 - acc: 0.0608 - val_loss: 4.4782 - val_acc: 0.0491
# Epoch 15/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.3506 - acc: 0.0635Epoch 00015: val_loss improved from 4.47818 to 4.43196, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 23s 3ms/step - loss: 4.3508 - acc: 0.0633 - val_loss: 4.4320 - val_acc: 0.0563
# Epoch 16/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.3196 - acc: 0.0710Epoch 00016: val_loss did not improve
# 6680/6680 [==============================] - 23s 3ms/step - loss: 4.3198 - acc: 0.0710 - val_loss: 4.4435 - val_acc: 0.0659
# Epoch 17/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.2856 - acc: 0.0685Epoch 00017: val_loss improved from 4.43196 to 4.38627, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 23s 3ms/step - loss: 4.2852 - acc: 0.0686 - val_loss: 4.3863 - val_acc: 0.0635
# Epoch 18/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.2490 - acc: 0.0772Epoch 00018: val_loss did not improve
# 6680/6680 [==============================] - 23s 3ms/step - loss: 4.2485 - acc: 0.0771 - val_loss: 4.3926 - val_acc: 0.0623
# Epoch 19/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.2175 - acc: 0.0770Epoch 00019: val_loss improved from 4.38627 to 4.33112, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 23s 3ms/step - loss: 4.2184 - acc: 0.0768 - val_loss: 4.3311 - val_acc: 0.0659
# Epoch 20/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.1955 - acc: 0.0781Epoch 00020: val_loss improved from 4.33112 to 4.29560, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 23s 3ms/step - loss: 4.1951 - acc: 0.0781 - val_loss: 4.2956 - val_acc: 0.0671

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
model.load_weights('saved_models/weights.best.from_scratch.hdf5')

# %% [markdown]
# ### Test the Model
#
# Try out your model on the test dataset of dog images.  Ensure that your test accuracy is greater than 1%.

# %%
# get index of predicted dog breed for each image in test set
dog_breed_predictions = [np.argmax(model.predict(np.expand_dims(tensor, axis=0))) for tensor in test_tensors]

# report test accuracy
test_accuracy = 100*np.sum(np.array(dog_breed_predictions)==np.argmax(test_targets, axis=1))/len(dog_breed_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 7.7751%

# %% [markdown]
# ---
# <a id='step4'></a>
# ## Step 4: Use a CNN to Classify Dog Breeds
#
# To reduce training time without sacrificing accuracy, we show you how to train a CNN using transfer learning.  In the following step, you will get a chance to use transfer learning to train your own CNN.
#
# ### Obtain Bottleneck Features

# %%
bottleneck_features = np.load('bottleneck_features/DogVGG16Data.npz')
train_VGG16 = bottleneck_features['train']
valid_VGG16 = bottleneck_features['valid']
test_VGG16 = bottleneck_features['test']

# %%
train_VGG16.shape
# Out:
# (6680, 7, 7, 512)

# %%
train_VGG16.shape[1:]
# Out:
# (7, 7, 512)

# %% [markdown]
# ### Model Architecture
#
# The model uses the the pre-trained VGG-16 model as a fixed feature extractor, where the last convolutional output of VGG-16 is fed as input to our model.  We only add a global average pooling layer and a fully connected layer, where the latter contains one node for each dog category and is equipped with a softmax.

# %%
VGG16_model = Sequential()
VGG16_model.add(GlobalAveragePooling2D(input_shape=train_VGG16.shape[1:]))
VGG16_model.add(Dense(133, activation='softmax'))

VGG16_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_2 ( (None, 512)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 133)               68229
# =================================================================
# Total params: 68,229
# Trainable params: 68,229
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile the Model

# %%
VGG16_model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %% [markdown]
# ### Train the Model

# %%
checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.VGG16.hdf5', 
                               verbose=1, save_best_only=True)

VGG16_model.fit(train_VGG16, train_targets, 
          validation_data=(valid_VGG16, valid_targets),
          epochs=20, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/20
# 6560/6680 [============================>.] - ETA: 0s - loss: 11.9802 - acc: 0.1255Epoch 00001: val_loss improved from inf to 10.33695, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 352us/step - loss: 11.9507 - acc: 0.1277 - val_loss: 10.3370 - val_acc: 0.2168
# Epoch 2/20
# 6500/6680 [============================>.] - ETA: 0s - loss: 9.6047 - acc: 0.3086Epoch 00002: val_loss improved from 10.33695 to 9.63795, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 252us/step - loss: 9.6264 - acc: 0.3084 - val_loss: 9.6380 - val_acc: 0.3006
# Epoch 3/20
# 6560/6680 [============================>.] - ETA: 0s - loss: 9.0838 - acc: 0.3674Epoch 00003: val_loss improved from 9.63795 to 9.15075, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 276us/step - loss: 9.0729 - acc: 0.3683 - val_loss: 9.1507 - val_acc: 0.3353
# Epoch 4/20
# 6520/6680 [============================>.] - ETA: 0s - loss: 8.6196 - acc: 0.4089Epoch 00004: val_loss improved from 9.15075 to 8.96134, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 257us/step - loss: 8.6236 - acc: 0.4082 - val_loss: 8.9613 - val_acc: 0.3473
# Epoch 5/20
# 6500/6680 [============================>.] - ETA: 0s - loss: 8.4047 - acc: 0.4417Epoch 00005: val_loss improved from 8.96134 to 8.92917, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 254us/step - loss: 8.4224 - acc: 0.4409 - val_loss: 8.9292 - val_acc: 0.3557
# Epoch 6/20
# 6640/6680 [============================>.] - ETA: 0s - loss: 8.3447 - acc: 0.4559Epoch 00006: val_loss improved from 8.92917 to 8.86733, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 277us/step - loss: 8.3414 - acc: 0.4560 - val_loss: 8.8673 - val_acc: 0.3749
# Epoch 7/20
# 6620/6680 [============================>.] - ETA: 0s - loss: 8.2811 - acc: 0.4651Epoch 00007: val_loss improved from 8.86733 to 8.85576, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 284us/step - loss: 8.2840 - acc: 0.4651 - val_loss: 8.8558 - val_acc: 0.3772
# Epoch 8/20
# 6520/6680 [============================>.] - ETA: 0s - loss: 8.2433 - acc: 0.4727Epoch 00008: val_loss did not improve
# 6680/6680 [==============================] - 2s 267us/step - loss: 8.2472 - acc: 0.4723 - val_loss: 8.8784 - val_acc: 0.3892
# Epoch 9/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 8.2334 - acc: 0.4752Epoch 00009: val_loss improved from 8.85576 to 8.83059, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 264us/step - loss: 8.2306 - acc: 0.4753 - val_loss: 8.8306 - val_acc: 0.3928
# Epoch 10/20
# 6600/6680 [============================>.] - ETA: 0s - loss: 8.0957 - acc: 0.4809Epoch 00010: val_loss improved from 8.83059 to 8.60157, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 276us/step - loss: 8.0930 - acc: 0.4813 - val_loss: 8.6016 - val_acc: 0.3964
# Epoch 11/20
# 6640/6680 [============================>.] - ETA: 0s - loss: 7.8336 - acc: 0.4953Epoch 00011: val_loss improved from 8.60157 to 8.48031, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 252us/step - loss: 7.8472 - acc: 0.4946 - val_loss: 8.4803 - val_acc: 0.4120
# Epoch 12/20
# 6500/6680 [============================>.] - ETA: 0s - loss: 7.7716 - acc: 0.5042Epoch 00012: val_loss improved from 8.48031 to 8.43934, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 271us/step - loss: 7.7734 - acc: 0.5039 - val_loss: 8.4393 - val_acc: 0.4144
# Epoch 13/20
# 6540/6680 [============================>.] - ETA: 0s - loss: 7.7295 - acc: 0.5092Epoch 00013: val_loss improved from 8.43934 to 8.41886, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 277us/step - loss: 7.7284 - acc: 0.5091 - val_loss: 8.4189 - val_acc: 0.4156
# Epoch 14/20
# 6620/6680 [============================>.] - ETA: 0s - loss: 7.5568 - acc: 0.5119Epoch 00014: val_loss improved from 8.41886 to 8.13002, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 259us/step - loss: 7.5507 - acc: 0.5123 - val_loss: 8.1300 - val_acc: 0.4144
# Epoch 15/20
# 6560/6680 [============================>.] - ETA: 0s - loss: 7.2535 - acc: 0.5322Epoch 00015: val_loss improved from 8.13002 to 7.93642, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 252us/step - loss: 7.2415 - acc: 0.5328 - val_loss: 7.9364 - val_acc: 0.4443
# Epoch 16/20
# 6640/6680 [============================>.] - ETA: 0s - loss: 7.1599 - acc: 0.5432Epoch 00016: val_loss improved from 7.93642 to 7.85402, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 276us/step - loss: 7.1605 - acc: 0.5433 - val_loss: 7.8540 - val_acc: 0.4455
# Epoch 17/20
# 6440/6680 [===========================>..] - ETA: 0s - loss: 7.0915 - acc: 0.5478Epoch 00017: val_loss did not improve
# 6680/6680 [==============================] - 2s 264us/step - loss: 7.1049 - acc: 0.5473 - val_loss: 7.8689 - val_acc: 0.4407
# Epoch 18/20
# 6540/6680 [============================>.] - ETA: 0s - loss: 7.0377 - acc: 0.5505Epoch 00018: val_loss improved from 7.85402 to 7.80089, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 252us/step - loss: 7.0411 - acc: 0.5503 - val_loss: 7.8009 - val_acc: 0.4479
# Epoch 19/20
# 6620/6680 [============================>.] - ETA: 0s - loss: 7.0111 - acc: 0.5559Epoch 00019: val_loss did not improve
# 6680/6680 [==============================] - 2s 286us/step - loss: 7.0086 - acc: 0.5561 - val_loss: 7.8331 - val_acc: 0.4491
# Epoch 20/20
# 6460/6680 [============================>.] - ETA: 0s - loss: 6.9939 - acc: 0.5584Epoch 00020: val_loss improved from 7.80089 to 7.78723, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 253us/step - loss: 6.9882 - acc: 0.5588 - val_loss: 7.7872 - val_acc: 0.4563

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
VGG16_model.load_weights('saved_models/weights.best.VGG16.hdf5')

# %% [markdown]
# ### Test the Model
#
# Now, we can use the CNN to test how well it identifies breed within our test dataset of dog images.  We print the test accuracy below.

# %%
# get index of predicted dog breed for each image in test set
VGG16_predictions = [np.argmax(VGG16_model.predict(np.expand_dims(feature, axis=0))) for feature in test_VGG16]

# report test accuracy
test_accuracy = 100*np.sum(np.array(VGG16_predictions)==np.argmax(test_targets, axis=1))/len(VGG16_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 45.6938%

# %% [markdown]
# ### Predict Dog Breed with the Model

# %%
from extract_bottleneck_features import *

def VGG16_predict_breed(img_path):
    # extract bottleneck features
    bottleneck_feature = extract_VGG16(path_to_tensor(img_path))
    # obtain predicted vector
    predicted_vector = VGG16_model.predict(bottleneck_feature)
    # return dog breed that is predicted by the model
    return dog_names[np.argmax(predicted_vector)]

# %%
dog_files_short[2]
# Out:
# '../../../data/dog_images/train/088.Irish_water_spaniel/Irish_water_spaniel_06014.jpg'

# %%
VGG16_predict_breed(dog_files_short[2])
# Out:
# 'ages/train/088.Irish_water_spaniel'

# %% [markdown]
# ---
# <a id='step5'></a>
# ## Step 5: Create a CNN to Classify Dog Breeds (using Transfer Learning)
#
# You will now use transfer learning to create a CNN that can identify dog breed from images.  Your CNN must attain at least 60% accuracy on the test set.
#
# In Step 4, we used transfer learning to create a CNN using VGG-16 bottleneck features.  In this section, you must use the bottleneck features from a different pre-trained model.  To make things easier for you, we have pre-computed the features for all of the networks that are currently available in Keras:
# - [VGG-19](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogVGG19Data.npz) bottleneck features
# - [ResNet-50](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogResnet50Data.npz) bottleneck features
# - [Inception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogInceptionV3Data.npz) bottleneck features
# - [Xception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogXceptionData.npz) bottleneck features
#
# The files are encoded as such:
#
#     Dog{network}Data.npz
#
# where `{network}`, in the above filename, can be one of `VGG19`, `Resnet50`, `InceptionV3`, or `Xception`.  Pick one of the above architectures, download the corresponding bottleneck features, and store the downloaded file in the `bottleneck_features/` folder in the repository.
#
# ### (IMPLEMENTATION) Obtain Bottleneck Features
#
# In the code block below, extract the bottleneck features corresponding to the train, test, and validation sets by running the following:
#
#     bottleneck_features = np.load('bottleneck_features/Dog{network}Data.npz')
#     train_{network} = bottleneck_features['train']
#     valid_{network} = bottleneck_features['valid']
#     test_{network} = bottleneck_features['test']

# %%
ls
# Out:
# bottleneck_features/  extract_bottleneck_features.py  __pycache__/
# CODEOWNERS            haarcascades/                   README.md
# dog_app.ipynb         images/                         requirements/
# dog_app-zh.ipynb      LICENSE.txt                     saved_models/

# %%
# !wget https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogXceptionData.npz -P bottleneck_features/
# Out:
# --2020-01-22 20:36:30--  https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogXceptionData.npz
# Resolving s3-us-west-1.amazonaws.com (s3-us-west-1.amazonaws.com)... 52.219.116.224
# Connecting to s3-us-west-1.amazonaws.com (s3-us-west-1.amazonaws.com)|52.219.116.224|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3352158914 (3.1G) [application/x-www-form-urlencoded]
# Saving to: ‘bottleneck_features/DogXceptionData.npz’
#
# DogXceptionData.npz  68%[============>       ]   2.15G  64.5MB/s    in 31s
#
#
# Cannot write to ‘bottleneck_features/DogXceptionData.npz’ (Success).

# %%
### TODO: Obtain bottleneck features from another pre-trained CNN.
bottleneck_features = np.load('/bottleneck_features/DogXceptionData.npz')
train_Xception = bottleneck_features['train']
valid_Xception = bottleneck_features['valid']
test_Xception = bottleneck_features['test']

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  At the end of your code cell block, summarize the layers of your model by executing the line:
#
#         <your model's name>.summary()
#
# __Question 5:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  Describe why you think the architecture is suitable for the current problem.
#
# __Answer:__

# %%
### TODO: Define your architecture.
Xception_model = Sequential()
Xception_model.add(GlobalAveragePooling2D(input_shape=train_Xception.shape[1:]))
Xception_model.add(Dense(133))
Xception_model.add(Dense(133))
Xception_model.add(Dense(133, activation='softmax'))

Xception_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_5 ( (None, 2048)              0
# _________________________________________________________________
# dense_21 (Dense)             (None, 133)               272517
# _________________________________________________________________
# dense_22 (Dense)             (None, 133)               17822
# _________________________________________________________________
# dense_23 (Dense)             (None, 133)               17822
# =================================================================
# Total params: 308,161
# Trainable params: 308,161
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### (IMPLEMENTATION) Compile the Model

# %%
### TODO: Compile the model.
Xception_model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %% [markdown]
# ### (IMPLEMENTATION) Train the Model
#
# Train your model in the code cell below.  Use model checkpointing to save the model that attains the best validation loss.
#
# You are welcome to [augment the training data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), but this is not a requirement.

# %%
### TODO: specify the number of epochs that you would like to use to train the model.

epochs = 20

### Do NOT modify the code below this line.

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.Xception_model.hdf5', 
                               verbose=1, save_best_only=True)

Xception_model.fit(train_Xception, train_targets, 
          validation_data=(valid_Xception, valid_targets),
          epochs=epochs, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/20
# 6600/6680 [============================>.] - ETA: 0s - loss: 1.2283 - acc: 0.6921Epoch 00001: val_loss improved from inf to 0.71432, saving model to saved_models/weights.best.Xception_model.hdf5
# 6680/6680 [==============================] - 4s 545us/step - loss: 1.2226 - acc: 0.6930 - val_loss: 0.7143 - val_acc: 0.7904
# Epoch 2/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.5488 - acc: 0.8312Epoch 00002: val_loss improved from 0.71432 to 0.68901, saving model to saved_models/weights.best.Xception_model.hdf5
# 6680/6680 [==============================] - 3s 458us/step - loss: 0.5499 - acc: 0.8307 - val_loss: 0.6890 - val_acc: 0.8096
# Epoch 3/20
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.4114 - acc: 0.8692Epoch 00003: val_loss did not improve
# 6680/6680 [==============================] - 3s 469us/step - loss: 0.4112 - acc: 0.8693 - val_loss: 0.7285 - val_acc: 0.7964
# Epoch 4/20
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.3205 - acc: 0.8982Epoch 00004: val_loss improved from 0.68901 to 0.65121, saving model to saved_models/weights.best.Xception_model.hdf5
# 6680/6680 [==============================] - 3s 462us/step - loss: 0.3222 - acc: 0.8976 - val_loss: 0.6512 - val_acc: 0.8024
# Epoch 5/20
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.2685 - acc: 0.9183Epoch 00005: val_loss did not improve
# 6680/6680 [==============================] - 3s 445us/step - loss: 0.2698 - acc: 0.9181 - val_loss: 0.7098 - val_acc: 0.8108
# Epoch 6/20
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.2195 - acc: 0.9282Epoch 00006: val_loss did not improve
# 6680/6680 [==============================] - 3s 444us/step - loss: 0.2181 - acc: 0.9293 - val_loss: 0.7640 - val_acc: 0.7964
# Epoch 7/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.1825 - acc: 0.9410Epoch 00007: val_loss did not improve
# 6680/6680 [==============================] - 3s 452us/step - loss: 0.1826 - acc: 0.9409 - val_loss: 0.8433 - val_acc: 0.8060
# Epoch 8/20
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.1517 - acc: 0.9492Epoch 00008: val_loss did not improve
# 6680/6680 [==============================] - 3s 465us/step - loss: 0.1517 - acc: 0.9493 - val_loss: 0.8366 - val_acc: 0.8036
# Epoch 9/20
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.1430 - acc: 0.9535Epoch 00009: val_loss did not improve
# 6680/6680 [==============================] - 3s 446us/step - loss: 0.1425 - acc: 0.9537 - val_loss: 0.7581 - val_acc: 0.8228
# Epoch 10/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.1175 - acc: 0.9613Epoch 00010: val_loss did not improve
# 6680/6680 [==============================] - 3s 447us/step - loss: 0.1177 - acc: 0.9611 - val_loss: 0.8162 - val_acc: 0.8311
# Epoch 11/20
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.1018 - acc: 0.9675Epoch 00011: val_loss did not improve
# 6680/6680 [==============================] - 3s 447us/step - loss: 0.1023 - acc: 0.9674 - val_loss: 0.8932 - val_acc: 0.8204
# Epoch 12/20
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0905 - acc: 0.9706Epoch 00012: val_loss did not improve
# 6680/6680 [==============================] - 3s 446us/step - loss: 0.0947 - acc: 0.9699 - val_loss: 0.9067 - val_acc: 0.8228
# Epoch 13/20
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0799 - acc: 0.9750Epoch 00013: val_loss did not improve
# 6680/6680 [==============================] - 3s 459us/step - loss: 0.0806 - acc: 0.9749 - val_loss: 0.9377 - val_acc: 0.8132
# Epoch 14/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0735 - acc: 0.9775Epoch 00014: val_loss did not improve
# 6680/6680 [==============================] - 3s 443us/step - loss: 0.0736 - acc: 0.9774 - val_loss: 0.9082 - val_acc: 0.8263
# Epoch 15/20
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.0748 - acc: 0.9777Epoch 00015: val_loss did not improve
# 6680/6680 [==============================] - 3s 466us/step - loss: 0.0758 - acc: 0.9774 - val_loss: 1.0097 - val_acc: 0.8192
# Epoch 16/20
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0629 - acc: 0.9818Epoch 00016: val_loss did not improve
# 6680/6680 [==============================] - 3s 456us/step - loss: 0.0641 - acc: 0.9811 - val_loss: 0.9426 - val_acc: 0.8299
# Epoch 17/20
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0594 - acc: 0.9825Epoch 00017: val_loss did not improve
# 6680/6680 [==============================] - 3s 484us/step - loss: 0.0612 - acc: 0.9825 - val_loss: 0.9582 - val_acc: 0.8299
# Epoch 18/20
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0522 - acc: 0.9866Epoch 00018: val_loss did not improve
# 6680/6680 [==============================] - 3s 455us/step - loss: 0.0522 - acc: 0.9865 - val_loss: 1.0987 - val_acc: 0.8192
# Epoch 19/20
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.0516 - acc: 0.9853Epoch 00019: val_loss did not improve
# 6680/6680 [==============================] - 3s 457us/step - loss: 0.0510 - acc: 0.9855 - val_loss: 1.0055 - val_acc: 0.8323
# Epoch 20/20
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.0449 - acc: 0.9853Epoch 00020: val_loss did not improve
# 6680/6680 [==============================] - 3s 454us/step - loss: 0.0449 - acc: 0.9852 - val_loss: 1.0475 - val_acc: 0.8299

# %% [markdown]
# ### (IMPLEMENTATION) Load the Model with the Best Validation Loss

# %%
### TODO: Load the model weights with the best validation loss.
Xception_model.load_weights('saved_models/weights.best.Xception_model.hdf5')

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images. Ensure that your test accuracy is greater than 60%.

# %%
### TODO: Calculate classification accuracy on the test dataset.
# get index of predicted dog breed for each image in test set
Xception_predictions = [np.argmax(Xception_model.predict(np.expand_dims(feature, axis=0))) for feature in test_Xception]

# report test accuracy
test_accuracy = 100*np.sum(np.array(Xception_predictions)==np.argmax(test_targets, axis=1))/len(Xception_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 83.3732%

# %% [markdown]
# ### (IMPLEMENTATION) Predict Dog Breed with the Model
#
# Write a function that takes an image path as input and returns the dog breed (`Affenpinscher`, `Afghan_hound`, etc) that is predicted by your model.
#
# Similar to the analogous function in Step 5, your function should have three steps:
# 1. Extract the bottleneck features corresponding to the chosen CNN model.
# 2. Supply the bottleneck features as input to the model to return the predicted vector.  Note that the argmax of this prediction vector gives the index of the predicted dog breed.
# 3. Use the `dog_names` array defined in Step 0 of this notebook to return the corresponding breed.
#
# The functions to extract the bottleneck features can be found in `extract_bottleneck_features.py`, and they have been imported in an earlier code cell.  To obtain the bottleneck features corresponding to your chosen CNN architecture, you need to use the function
#
#     extract_{network}
#
# where `{network}`, in the above filename, should be one of `VGG19`, `Resnet50`, `InceptionV3`, or `Xception`.

# %%
### TODO: Write a function that takes a path to an image as input
### and returns the dog breed that is predicted by the model.
from extract_bottleneck_features import *

def Xception_predict_breed(img_path):
    # extract bottleneck features
    bottleneck_feature = extract_Xception(path_to_tensor(img_path))
    # obtain predicted vector
    predicted_vector = Xception_model.predict(bottleneck_feature)
    # return dog breed that is predicted by the model
    return dog_names[np.argmax(predicted_vector)]

# %%
Xception_predict_breed(dog_files_short[1])
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.4/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 1s 0us/step
# 'ages/train/057.Dalmatian'

# %%
for i in range(10):
    print(Xception_predict_breed(dog_files_short[i]), dog_files_short[i])
# Out:
# ages/train/095.Kuvasz ../../../data/dog_images/train/095.Kuvasz/Kuvasz_06442.jpg
# ages/train/057.Dalmatian ../../../data/dog_images/train/057.Dalmatian/Dalmatian_04054.jpg
# ages/train/009.American_water_spaniel ../../../data/dog_images/train/088.Irish_water_spaniel/Irish_water_spaniel_06014.jpg
# ages/train/008.American_staffordshire_terrier ../../../data/dog_images/train/008.American_staffordshire_terrier/American_staffordshire_terrier_00596.jpg
# ages/train/008.American_staffordshire_terrier ../../../data/dog_images/train/008.American_staffordshire_terrier/American_staffordshire_terrier_00563.jpg
# ages/train/063.English_springer_spaniel ../../../data/dog_images/train/063.English_springer_spaniel/English_springer_spaniel_04469.jpg
# ages/train/054.Collie ../../../data/dog_images/train/054.Collie/Collie_03789.jpg
# ages/train/119.Petit_basset_griffon_vendeen ../../../data/dog_images/train/119.Petit_basset_griffon_vendeen/Petit_basset_griffon_vendeen_07705.jpg
# ages/train/009.American_water_spaniel ../../../data/dog_images/train/009.American_water_spaniel/American_water_spaniel_00625.jpg
# ages/train/081.Greyhound ../../../data/dog_images/train/081.Greyhound/Greyhound_05559.jpg

# %% [markdown]
# ---
# <a id='step6'></a>
# ## Step 6: Write your Algorithm
#
# Write an algorithm that accepts a file path to an image and first determines whether the image contains a human, dog, or neither.  Then,
# - if a __dog__ is detected in the image, return the predicted breed.
# - if a __human__ is detected in the image, return the resembling dog breed.
# - if __neither__ is detected in the image, provide output that indicates an error.
#
# You are welcome to write your own functions for detecting humans and dogs in images, but feel free to use the `face_detector` and `dog_detector` functions developed above.  You are __required__ to use your CNN from Step 5 to predict dog breed.
#
# A sample image and output for our algorithm is provided below, but feel free to design your own user experience!
#
# ![Sample Human Output](images/sample_human_2.png)
#
# This photo looks like an Afghan Hound.
# ### (IMPLEMENTATION) Write your Algorithm

# %%
import numpy as np
from keras.applications.resnet50 import ResNet50, decode_predictions
from keras.applications.resnet50 import preprocess_input as rn50_preprocess_input
from keras.applications.inception_resnet_v2 import InceptionResNetV2
from keras.applications.inception_resnet_v2 import preprocess_input as irnv2_preproccess_input
from keras.utils import np_utils
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint  
from keras.preprocessing import image                  
from tqdm import tqdm
from sklearn.datasets import load_files
from glob import glob
from PIL import ImageFile                            
ImageFile.LOAD_TRUNCATED_IMAGES = True
# Out:
# Using TensorFlow backend.

# %%
# define function to load train, test, and validation datasets
def load_dataset(path):
    data = load_files(path)
    dog_files = np.array(data['filenames'])
    dog_targets = np_utils.to_categorical(np.array(data['target']), 133)
    return dog_files, dog_targets

# load train, test, and validation datasets
train_files, train_targets = load_dataset('../../../data/dog_images/train')
valid_files, valid_targets = load_dataset('../../../data/dog_images/valid')
test_files, test_targets = load_dataset('../../../data/dog_images/test')

# load list of dog names
dog_names = [item[35:-1] for item in sorted(glob("../../../data/dog_images/train/*/"))]

# print statistics about the dataset
print('There are %d total dog categories.' % len(dog_names))
print('There are %s total dog images.\n' % len(np.hstack([train_files, valid_files, test_files])))
print('There are %d training dog images.' % len(train_files))
print('There are %d validation dog images.' % len(valid_files))
print('There are %d test dog images.'% len(test_files))
# Out:
# There are 133 total dog categories.
# There are 8351 total dog images.
#
# There are 6680 training dog images.
# There are 835 validation dog images.
# There are 836 test dog images.

# %% [markdown]
# Using the ResNet50 model

# %%
# define ResNet50 model to create a doggo or no doggo detector
ResNet50_model = ResNet50(weights='imagenet')

# %%
def path_to_tensor(img_path):
    # loads RGB image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=(224, 224))
    # convert PIL.Image.Image type to 3D tensor with shape (224, 224, 3)
    x = image.img_to_array(img)
    # convert 3D tensor to 4D tensor with shape (1, 224, 224, 3) and return 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %%
def ResNet50_predict_labels(img_path):
    # returns prediction vector for image located at img_path
    img = rn50_preprocess_input(path_to_tensor(img_path))
    return np.argmax(ResNet50_model.predict(img))

# %%
### returns "True" if a dog is detected in the image stored at img_path
def dog_detector(img_path):
    prediction = ResNet50_predict_labels(img_path)
    return ((prediction <= 268) & (prediction >= 151))

# %%
ResNet50_predict_labels('images/sample_human_2.png')
# Out:
# 903

# %%
dog_detector('images/sample_human_output.png')
# Out:
# False

# %%
dog_detector('images/Labrador_retriever_06449.jpg')
# Out:
# True

# %%
# pre-process the data for Keras
train_tensors = paths_to_tensor(train_files).astype('float32')/255
valid_tensors = paths_to_tensor(valid_files).astype('float32')/255
test_tensors = paths_to_tensor(test_files).astype('float32')/255
# Out:
# 100%|██████████| 6680/6680 [01:12<00:00, 91.70it/s]
# 100%|██████████| 835/835 [00:08<00:00, 102.67it/s]
# 100%|██████████| 836/836 [00:08<00:00, 103.74it/s]

# %%
# Transfer learning using the inceptionresnetv2 trained on imagenet
model_cropped = InceptionResNetV2(weights='imagenet', include_top=False)
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.7/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219062272/219055592 [==============================] - 3s 0us/step

# %%
model_cropped.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, None, 3 864         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, None, None, 3 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, None, None, 3 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, None, None, 3 9216        activation_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, None, None, 3 96          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, None, None, 3 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, None, None, 6 18432       activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, None, None, 6 192         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, None, None, 6 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, None, None, 6 0           activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, None, None, 8 5120        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, None, None, 8 240         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, None, None, 8 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, None, None, 1 138240      activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, None, None, 1 576         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, None, None, 1 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, None, None, 1 0           activation_54[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, None, None, 6 12288       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, None, None, 6 192         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, None, None, 6 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, None, None, 4 9216        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, None, None, 9 55296       activation_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, None, None, 4 144         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, None, None, 9 288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, None, None, 4 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, None, None, 9 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, None, None, 1 0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, None, None, 9 18432       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, None, None, 6 76800       activation_56[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, None, None, 9 82944       activation_59[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, None, None, 6 12288       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, None, None, 9 288         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, None, None, 6 192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, None, None, 9 288         conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, None, None, 6 192         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, None, None, 9 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, None, None, 6 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, None, None, 9 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, None, None, 6 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# mixed_5b (Concatenate)          (None, None, None, 3 0           activation_55[0][0]
#                                                                  activation_57[0][0]
#                                                                  activation_60[0][0]
#                                                                  activation_61[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, None, None, 3 10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, None, None, 3 96          conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, None, None, 3 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, None, None, 3 10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, None, None, 4 13824       activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, None, None, 3 96          conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, None, None, 4 144         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, None, None, 3 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, None, None, 4 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, None, None, 3 10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, None, None, 3 9216        activation_63[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, None, None, 6 27648       activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, None, None, 3 96          conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, None, None, 3 96          conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, None, None, 6 192         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, None, None, 3 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, None, None, 3 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, None, None, 6 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# block35_1_mixed (Concatenate)   (None, None, None, 1 0           activation_62[0][0]
#                                                                  activation_64[0][0]
#                                                                  activation_67[0][0]
# __________________________________________________________________________________________________
# block35_1_conv (Conv2D)         (None, None, None, 3 41280       block35_1_mixed[0][0]
# __________________________________________________________________________________________________
# block35_1 (Lambda)              (None, None, None, 3 0           mixed_5b[0][0]
#                                                                  block35_1_conv[0][0]
# __________________________________________________________________________________________________
# block35_1_ac (Activation)       (None, None, None, 3 0           block35_1[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, None, None, 3 10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, None, None, 3 96          conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, None, None, 3 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, None, None, 3 10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, None, None, 4 13824       activation_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, None, None, 3 96          conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, None, None, 4 144         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, None, None, 3 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, None, None, 4 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, None, None, 3 10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, None, None, 3 9216        activation_69[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, None, None, 6 27648       activation_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, None, None, 3 96          conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, None, None, 3 96          conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, None, None, 6 192         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, None, None, 3 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, None, None, 3 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, None, None, 6 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# block35_2_mixed (Concatenate)   (None, None, None, 1 0           activation_68[0][0]
#                                                                  activation_70[0][0]
#                                                                  activation_73[0][0]
# __________________________________________________________________________________________________
# block35_2_conv (Conv2D)         (None, None, None, 3 41280       block35_2_mixed[0][0]
# __________________________________________________________________________________________________
# block35_2 (Lambda)              (None, None, None, 3 0           block35_1_ac[0][0]
#                                                                  block35_2_conv[0][0]
# __________________________________________________________________________________________________
# block35_2_ac (Activation)       (None, None, None, 3 0           block35_2[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, None, None, 3 10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, None, None, 3 96          conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, None, None, 3 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, None, None, 3 10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, None, None, 4 13824       activation_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, None, None, 3 96          conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, None, None, 4 144         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, None, None, 3 0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, None, None, 4 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, None, None, 3 10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, None, None, 3 9216        activation_75[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, None, None, 6 27648       activation_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, None, None, 3 96          conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, None, None, 3 96          conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, None, None, 6 192         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, None, None, 3 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, None, None, 3 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, None, None, 6 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# block35_3_mixed (Concatenate)   (None, None, None, 1 0           activation_74[0][0]
#                                                                  activation_76[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# block35_3_conv (Conv2D)         (None, None, None, 3 41280       block35_3_mixed[0][0]
# __________________________________________________________________________________________________
# block35_3 (Lambda)              (None, None, None, 3 0           block35_2_ac[0][0]
#                                                                  block35_3_conv[0][0]
# __________________________________________________________________________________________________
# block35_3_ac (Activation)       (None, None, None, 3 0           block35_3[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, None, None, 3 10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, None, None, 3 96          conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, None, None, 3 0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, None, None, 3 10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, None, None, 4 13824       activation_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, None, None, 3 96          conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, None, None, 4 144         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, None, None, 3 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, None, None, 4 0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, None, None, 3 10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, None, None, 3 9216        activation_81[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, None, None, 6 27648       activation_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, None, None, 3 96          conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, None, None, 3 96          conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, None, None, 6 192         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, None, None, 3 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, None, None, 3 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, None, None, 6 0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# block35_4_mixed (Concatenate)   (None, None, None, 1 0           activation_80[0][0]
#                                                                  activation_82[0][0]
#                                                                  activation_85[0][0]
# __________________________________________________________________________________________________
# block35_4_conv (Conv2D)         (None, None, None, 3 41280       block35_4_mixed[0][0]
# __________________________________________________________________________________________________
# block35_4 (Lambda)              (None, None, None, 3 0           block35_3_ac[0][0]
#                                                                  block35_4_conv[0][0]
# __________________________________________________________________________________________________
# block35_4_ac (Activation)       (None, None, None, 3 0           block35_4[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, None, None, 3 10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, None, None, 3 96          conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, None, None, 3 0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, None, None, 3 10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, None, None, 4 13824       activation_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, None, None, 3 96          conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, None, None, 4 144         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, None, None, 3 0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, None, None, 4 0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, None, None, 3 10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, None, None, 3 9216        activation_87[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, None, None, 6 27648       activation_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, None, None, 3 96          conv2d_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, None, None, 3 96          conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, None, None, 6 192         conv2d_42[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, None, None, 3 0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, None, None, 3 0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, None, None, 6 0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# block35_5_mixed (Concatenate)   (None, None, None, 1 0           activation_86[0][0]
#                                                                  activation_88[0][0]
#                                                                  activation_91[0][0]
# __________________________________________________________________________________________________
# block35_5_conv (Conv2D)         (None, None, None, 3 41280       block35_5_mixed[0][0]
# __________________________________________________________________________________________________
# block35_5 (Lambda)              (None, None, None, 3 0           block35_4_ac[0][0]
#                                                                  block35_5_conv[0][0]
# __________________________________________________________________________________________________
# block35_5_ac (Activation)       (None, None, None, 3 0           block35_5[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, None, None, 3 10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, None, None, 3 96          conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, None, None, 3 0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, None, None, 3 10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, None, None, 4 13824       activation_95[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, None, None, 3 96          conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, None, None, 4 144         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, None, None, 3 0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, None, None, 4 0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, None, None, 3 10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, None, None, 3 9216        activation_93[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, None, None, 6 27648       activation_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, None, None, 3 96          conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, None, None, 3 96          conv2d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, None, None, 6 192         conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, None, None, 3 0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, None, None, 3 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, None, None, 6 0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# block35_6_mixed (Concatenate)   (None, None, None, 1 0           activation_92[0][0]
#                                                                  activation_94[0][0]
#                                                                  activation_97[0][0]
# __________________________________________________________________________________________________
# block35_6_conv (Conv2D)         (None, None, None, 3 41280       block35_6_mixed[0][0]
# __________________________________________________________________________________________________
# block35_6 (Lambda)              (None, None, None, 3 0           block35_5_ac[0][0]
#                                                                  block35_6_conv[0][0]
# __________________________________________________________________________________________________
# block35_6_ac (Activation)       (None, None, None, 3 0           block35_6[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, None, None, 3 10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, None, None, 3 96          conv2d_52[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, None, None, 3 0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, None, None, 3 10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, None, None, 4 13824       activation_101[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, None, None, 3 96          conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, None, None, 4 144         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, None, None, 3 0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, None, None, 4 0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, None, None, 3 10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, None, None, 3 9216        activation_99[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, None, None, 6 27648       activation_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, None, None, 3 96          conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, None, None, 3 96          conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, None, None, 6 192         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, None, None, 3 0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, None, None, 3 0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, None, None, 6 0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# block35_7_mixed (Concatenate)   (None, None, None, 1 0           activation_98[0][0]
#                                                                  activation_100[0][0]
#                                                                  activation_103[0][0]
# __________________________________________________________________________________________________
# block35_7_conv (Conv2D)         (None, None, None, 3 41280       block35_7_mixed[0][0]
# __________________________________________________________________________________________________
# block35_7 (Lambda)              (None, None, None, 3 0           block35_6_ac[0][0]
#                                                                  block35_7_conv[0][0]
# __________________________________________________________________________________________________
# block35_7_ac (Activation)       (None, None, None, 3 0           block35_7[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, None, None, 3 10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, None, None, 3 96          conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, None, None, 3 0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, None, None, 3 10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, None, None, 4 13824       activation_107[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, None, None, 3 96          conv2d_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, None, None, 4 144         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, None, None, 3 0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, None, None, 4 0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, None, None, 3 10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, None, None, 3 9216        activation_105[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, None, None, 6 27648       activation_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, None, None, 3 96          conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, None, None, 3 96          conv2d_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, None, None, 6 192         conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, None, None, 3 0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, None, None, 3 0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, None, None, 6 0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# block35_8_mixed (Concatenate)   (None, None, None, 1 0           activation_104[0][0]
#                                                                  activation_106[0][0]
#                                                                  activation_109[0][0]
# __________________________________________________________________________________________________
# block35_8_conv (Conv2D)         (None, None, None, 3 41280       block35_8_mixed[0][0]
# __________________________________________________________________________________________________
# block35_8 (Lambda)              (None, None, None, 3 0           block35_7_ac[0][0]
#                                                                  block35_8_conv[0][0]
# __________________________________________________________________________________________________
# block35_8_ac (Activation)       (None, None, None, 3 0           block35_8[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, None, None, 3 10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, None, None, 3 96          conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_113 (Activation)     (None, None, None, 3 0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, None, None, 3 10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, None, None, 4 13824       activation_113[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, None, None, 3 96          conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, None, None, 4 144         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_111 (Activation)     (None, None, None, 3 0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_114 (Activation)     (None, None, None, 4 0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, None, None, 3 10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# batch_normalization_184 (BatchN (None, None, None, 1 576         conv2d_184[0][0]
# __________________________________________________________________________________________________
# batch_normalization_187 (BatchN (None, None, None, 2 768         conv2d_187[0][0]
# __________________________________________________________________________________________________
# activation_233 (Activation)     (None, None, None, 1 0           batch_normalization_184[0][0]
# __________________________________________________________________________________________________
# activation_236 (Activation)     (None, None, None, 2 0           batch_normalization_187[0][0]
# __________________________________________________________________________________________________
# block8_6_mixed (Concatenate)    (None, None, None, 4 0           activation_233[0][0]
#                                                                  activation_236[0][0]
# __________________________________________________________________________________________________
# block8_6_conv (Conv2D)          (None, None, None, 2 933920      block8_6_mixed[0][0]
# __________________________________________________________________________________________________
# block8_6 (Lambda)               (None, None, None, 2 0           block8_5_ac[0][0]
#                                                                  block8_6_conv[0][0]
# __________________________________________________________________________________________________
# block8_6_ac (Activation)        (None, None, None, 2 0           block8_6[0][0]
# __________________________________________________________________________________________________
# conv2d_189 (Conv2D)             (None, None, None, 1 399360      block8_6_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_189 (BatchN (None, None, None, 1 576         conv2d_189[0][0]
# __________________________________________________________________________________________________
# activation_238 (Activation)     (None, None, None, 1 0           batch_normalization_189[0][0]
# __________________________________________________________________________________________________
# conv2d_190 (Conv2D)             (None, None, None, 2 129024      activation_238[0][0]
# __________________________________________________________________________________________________
# batch_normalization_190 (BatchN (None, None, None, 2 672         conv2d_190[0][0]
# __________________________________________________________________________________________________
# activation_239 (Activation)     (None, None, None, 2 0           batch_normalization_190[0][0]
# __________________________________________________________________________________________________
# conv2d_188 (Conv2D)             (None, None, None, 1 399360      block8_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_191 (Conv2D)             (None, None, None, 2 172032      activation_239[0][0]
# __________________________________________________________________________________________________
# batch_normalization_188 (BatchN (None, None, None, 1 576         conv2d_188[0][0]
# __________________________________________________________________________________________________
# batch_normalization_191 (BatchN (None, None, None, 2 768         conv2d_191[0][0]
# __________________________________________________________________________________________________
# activation_237 (Activation)     (None, None, None, 1 0           batch_normalization_188[0][0]
# __________________________________________________________________________________________________
# activation_240 (Activation)     (None, None, None, 2 0           batch_normalization_191[0][0]
# __________________________________________________________________________________________________
# block8_7_mixed (Concatenate)    (None, None, None, 4 0           activation_237[0][0]
#                                                                  activation_240[0][0]
# __________________________________________________________________________________________________
# block8_7_conv (Conv2D)          (None, None, None, 2 933920      block8_7_mixed[0][0]
# __________________________________________________________________________________________________
# block8_7 (Lambda)               (None, None, None, 2 0           block8_6_ac[0][0]
#                                                                  block8_7_conv[0][0]
# __________________________________________________________________________________________________
# block8_7_ac (Activation)        (None, None, None, 2 0           block8_7[0][0]
# __________________________________________________________________________________________________
# conv2d_193 (Conv2D)             (None, None, None, 1 399360      block8_7_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_193 (BatchN (None, None, None, 1 576         conv2d_193[0][0]
# __________________________________________________________________________________________________
# activation_242 (Activation)     (None, None, None, 1 0           batch_normalization_193[0][0]
# __________________________________________________________________________________________________
# conv2d_194 (Conv2D)             (None, None, None, 2 129024      activation_242[0][0]
# __________________________________________________________________________________________________
# batch_normalization_194 (BatchN (None, None, None, 2 672         conv2d_194[0][0]
# __________________________________________________________________________________________________
# activation_243 (Activation)     (None, None, None, 2 0           batch_normalization_194[0][0]
# __________________________________________________________________________________________________
# conv2d_192 (Conv2D)             (None, None, None, 1 399360      block8_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_195 (Conv2D)             (None, None, None, 2 172032      activation_243[0][0]
# __________________________________________________________________________________________________
# batch_normalization_192 (BatchN (None, None, None, 1 576         conv2d_192[0][0]
# __________________________________________________________________________________________________
# batch_normalization_195 (BatchN (None, None, None, 2 768         conv2d_195[0][0]
# __________________________________________________________________________________________________
# activation_241 (Activation)     (None, None, None, 1 0           batch_normalization_192[0][0]
# __________________________________________________________________________________________________
# activation_244 (Activation)     (None, None, None, 2 0           batch_normalization_195[0][0]
# __________________________________________________________________________________________________
# block8_8_mixed (Concatenate)    (None, None, None, 4 0           activation_241[0][0]
#                                                                  activation_244[0][0]
# __________________________________________________________________________________________________
# block8_8_conv (Conv2D)          (None, None, None, 2 933920      block8_8_mixed[0][0]
# __________________________________________________________________________________________________
# block8_8 (Lambda)               (None, None, None, 2 0           block8_7_ac[0][0]
#                                                                  block8_8_conv[0][0]
# __________________________________________________________________________________________________
# block8_8_ac (Activation)        (None, None, None, 2 0           block8_8[0][0]
# __________________________________________________________________________________________________
# conv2d_197 (Conv2D)             (None, None, None, 1 399360      block8_8_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_197 (BatchN (None, None, None, 1 576         conv2d_197[0][0]
# __________________________________________________________________________________________________
# activation_246 (Activation)     (None, None, None, 1 0           batch_normalization_197[0][0]
# __________________________________________________________________________________________________
# conv2d_198 (Conv2D)             (None, None, None, 2 129024      activation_246[0][0]
# __________________________________________________________________________________________________
# batch_normalization_198 (BatchN (None, None, None, 2 672         conv2d_198[0][0]
# __________________________________________________________________________________________________
# activation_247 (Activation)     (None, None, None, 2 0           batch_normalization_198[0][0]
# __________________________________________________________________________________________________
# conv2d_196 (Conv2D)             (None, None, None, 1 399360      block8_8_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_199 (Conv2D)             (None, None, None, 2 172032      activation_247[0][0]
# __________________________________________________________________________________________________
# batch_normalization_196 (BatchN (None, None, None, 1 576         conv2d_196[0][0]
# __________________________________________________________________________________________________
# batch_normalization_199 (BatchN (None, None, None, 2 768         conv2d_199[0][0]
# __________________________________________________________________________________________________
# activation_245 (Activation)     (None, None, None, 1 0           batch_normalization_196[0][0]
# __________________________________________________________________________________________________
# activation_248 (Activation)     (None, None, None, 2 0           batch_normalization_199[0][0]
# __________________________________________________________________________________________________
# block8_9_mixed (Concatenate)    (None, None, None, 4 0           activation_245[0][0]
#                                                                  activation_248[0][0]
# __________________________________________________________________________________________________
# block8_9_conv (Conv2D)          (None, None, None, 2 933920      block8_9_mixed[0][0]
# __________________________________________________________________________________________________
# block8_9 (Lambda)               (None, None, None, 2 0           block8_8_ac[0][0]
#                                                                  block8_9_conv[0][0]
# __________________________________________________________________________________________________
# block8_9_ac (Activation)        (None, None, None, 2 0           block8_9[0][0]
# __________________________________________________________________________________________________
# conv2d_201 (Conv2D)             (None, None, None, 1 399360      block8_9_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_201 (BatchN (None, None, None, 1 576         conv2d_201[0][0]
# __________________________________________________________________________________________________
# activation_250 (Activation)     (None, None, None, 1 0           batch_normalization_201[0][0]
# __________________________________________________________________________________________________
# conv2d_202 (Conv2D)             (None, None, None, 2 129024      activation_250[0][0]
# __________________________________________________________________________________________________
# batch_normalization_202 (BatchN (None, None, None, 2 672         conv2d_202[0][0]
# __________________________________________________________________________________________________
# activation_251 (Activation)     (None, None, None, 2 0           batch_normalization_202[0][0]
# __________________________________________________________________________________________________
# conv2d_200 (Conv2D)             (None, None, None, 1 399360      block8_9_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_203 (Conv2D)             (None, None, None, 2 172032      activation_251[0][0]
# __________________________________________________________________________________________________
# batch_normalization_200 (BatchN (None, None, None, 1 576         conv2d_200[0][0]
# __________________________________________________________________________________________________
# batch_normalization_203 (BatchN (None, None, None, 2 768         conv2d_203[0][0]
# __________________________________________________________________________________________________
# activation_249 (Activation)     (None, None, None, 1 0           batch_normalization_200[0][0]
# __________________________________________________________________________________________________
# activation_252 (Activation)     (None, None, None, 2 0           batch_normalization_203[0][0]
# __________________________________________________________________________________________________
# block8_10_mixed (Concatenate)   (None, None, None, 4 0           activation_249[0][0]
#                                                                  activation_252[0][0]
# __________________________________________________________________________________________________
# block8_10_conv (Conv2D)         (None, None, None, 2 933920      block8_10_mixed[0][0]
# __________________________________________________________________________________________________
# block8_10 (Lambda)              (None, None, None, 2 0           block8_9_ac[0][0]
#                                                                  block8_10_conv[0][0]
# __________________________________________________________________________________________________
# conv_7b (Conv2D)                (None, None, None, 1 3194880     block8_10[0][0]
# __________________________________________________________________________________________________
# conv_7b_bn (BatchNormalization) (None, None, None, 1 4608        conv_7b[0][0]
# __________________________________________________________________________________________________
# conv_7b_ac (Activation)         (None, None, None, 1 0           conv_7b_bn[0][0]
# ==================================================================================================
# Total params: 54,336,736
# Trainable params: 54,276,192
# Non-trainable params: 60,544
# __________________________________________________________________________________________________

# %%
for l in model_cropped.layers:
    print (l.output_shape)
# Out:
# (None, None, None, 3)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 64)
# (None, None, None, 64)
# (None, None, None, 64)
# (None, None, None, 64)
# (None, None, None, 80)
# (None, None, None, 80)
# (None, None, None, 80)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 64)
# (None, None, None, 64)
# (None, None, None, 64)
# (None, None, None, 48)
# (None, None, None, 96)
# (None, None, None, 48)
# (None, None, None, 96)
# (None, None, None, 48)
# (None, None, None, 96)
# (None, None, None, 192)
# (None, None, None, 96)
# (None, None, None, 64)
# (None, None, None, 96)
# (None, None, None, 64)
# (None, None, None, 96)
# (None, None, None, 64)
# (None, None, None, 96)
# (None, None, None, 64)
# (None, None, None, 96)
# (None, None, None, 64)
# (None, None, None, 96)
# (None, None, None, 64)
# (None, None, None, 320)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 48)
# (None, None, None, 32)
# (None, None, None, 48)
# (None, None, None, 32)
# (None, None, None, 48)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 64)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 64)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 64)
# (None, None, None, 128)
# (None, None, None, 320)
# (None, None, None, 320)
# (None, None, None, 320)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 48)
# (None, None, None, 32)
# (None, None, None, 48)
# (None, None, None, 32)
# (None, None, None, 48)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 64)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 64)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 64)
# (None, None, None, 128)
# (None, None, None, 320)
# (None, None, None, 320)
# (None, None, None, 320)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 48)
# (None, None, None, 32)
# (None, None, None, 48)
# (None, None, None, 32)
# (None, None, None, 48)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 64)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 64)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 64)
# (None, None, None, 128)
# (None, None, None, 320)
# (None, None, None, 320)
# (None, None, None, 320)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 48)
# (None, None, None, 32)
# (None, None, None, 48)
# (None, None, None, 32)
# (None, None, None, 48)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 64)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 64)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 64)
# (None, None, None, 128)
# (None, None, None, 320)
# (None, None, None, 320)
# (None, None, None, 320)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 48)
# (None, None, None, 32)
# (None, None, None, 48)
# (None, None, None, 32)
# (None, None, None, 48)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 64)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 64)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 64)
# (None, None, None, 128)
# (None, None, None, 320)
# (None, None, None, 320)
# (None, None, None, 320)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 48)
# (None, None, None, 32)
# (None, None, None, 48)
# (None, None, None, 32)
# (None, None, None, 48)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 64)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 64)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 64)
# (None, None, None, 128)
# (None, None, None, 320)
# (None, None, None, 320)
# (None, None, None, 320)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 48)
# (None, None, None, 32)
# (None, None, None, 48)
# (None, None, None, 32)
# (None, None, None, 48)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 64)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 64)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 64)
# (None, None, None, 128)
# (None, None, None, 320)
# (None, None, None, 320)
# (None, None, None, 320)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 48)
# (None, None, None, 32)
# (None, None, None, 48)
# (None, None, None, 32)
# (None, None, None, 48)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 64)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 64)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 64)
# (None, None, None, 128)
# (None, None, None, 320)
# (None, None, None, 320)
# (None, None, None, 320)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 48)
# (None, None, None, 32)
# (None, None, None, 48)
# (None, None, None, 32)
# (None, None, None, 48)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 64)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 64)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 64)
# (None, None, None, 128)
# (None, None, None, 320)
# (None, None, None, 320)
# (None, None, None, 320)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 48)
# (None, None, None, 32)
# (None, None, None, 48)
# (None, None, None, 32)
# (None, None, None, 48)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 64)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 64)
# (None, None, None, 32)
# (None, None, None, 32)
# (None, None, None, 64)
# (None, None, None, 128)
# (None, None, None, 320)
# (None, None, None, 320)
# (None, None, None, 320)
# (None, None, None, 256)
# (None, None, None, 256)
# (None, None, None, 256)
# (None, None, None, 256)
# (None, None, None, 256)
# (None, None, None, 256)
# (None, None, None, 384)
# (None, None, None, 384)
# (None, None, None, 384)
# (None, None, None, 384)
# (None, None, None, 384)
# (None, None, None, 384)
# (None, None, None, 320)
# (None, None, None, 1088)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 384)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 384)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 384)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 384)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 384)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 384)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 384)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 384)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 384)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 384)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 384)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 384)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 384)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 384)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 384)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 384)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 384)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 384)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 384)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 128)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 160)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 384)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 1088)
# (None, None, None, 256)
# (None, None, None, 256)
# (None, None, None, 256)
# (None, None, None, 256)
# (None, None, None, 256)
# (None, None, None, 288)
# (None, None, None, 256)
# (None, None, None, 256)
# (None, None, None, 288)
# (None, None, None, 256)
# (None, None, None, 256)
# (None, None, None, 288)
# (None, None, None, 384)
# (None, None, None, 288)
# (None, None, None, 320)
# (None, None, None, 384)
# (None, None, None, 288)
# (None, None, None, 320)
# (None, None, None, 384)
# (None, None, None, 288)
# (None, None, None, 320)
# (None, None, None, 1088)
# (None, None, None, 2080)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 224)
# (None, None, None, 224)
# (None, None, None, 224)
# (None, None, None, 192)
# (None, None, None, 256)
# (None, None, None, 192)
# (None, None, None, 256)
# (None, None, None, 192)
# (None, None, None, 256)
# (None, None, None, 448)
# (None, None, None, 2080)
# (None, None, None, 2080)
# (None, None, None, 2080)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 224)
# (None, None, None, 224)
# (None, None, None, 224)
# (None, None, None, 192)
# (None, None, None, 256)
# (None, None, None, 192)
# (None, None, None, 256)
# (None, None, None, 192)
# (None, None, None, 256)
# (None, None, None, 448)
# (None, None, None, 2080)
# (None, None, None, 2080)
# (None, None, None, 2080)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 224)
# (None, None, None, 224)
# (None, None, None, 224)
# (None, None, None, 192)
# (None, None, None, 256)
# (None, None, None, 192)
# (None, None, None, 256)
# (None, None, None, 192)
# (None, None, None, 256)
# (None, None, None, 448)
# (None, None, None, 2080)
# (None, None, None, 2080)
# (None, None, None, 2080)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 224)
# (None, None, None, 224)
# (None, None, None, 224)
# (None, None, None, 192)
# (None, None, None, 256)
# (None, None, None, 192)
# (None, None, None, 256)
# (None, None, None, 192)
# (None, None, None, 256)
# (None, None, None, 448)
# (None, None, None, 2080)
# (None, None, None, 2080)
# (None, None, None, 2080)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 224)
# (None, None, None, 224)
# (None, None, None, 224)
# (None, None, None, 192)
# (None, None, None, 256)
# (None, None, None, 192)
# (None, None, None, 256)
# (None, None, None, 192)
# (None, None, None, 256)
# (None, None, None, 448)
# (None, None, None, 2080)
# (None, None, None, 2080)
# (None, None, None, 2080)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 224)
# (None, None, None, 224)
# (None, None, None, 224)
# (None, None, None, 192)
# (None, None, None, 256)
# (None, None, None, 192)
# (None, None, None, 256)
# (None, None, None, 192)
# (None, None, None, 256)
# (None, None, None, 448)
# (None, None, None, 2080)
# (None, None, None, 2080)
# (None, None, None, 2080)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 224)
# (None, None, None, 224)
# (None, None, None, 224)
# (None, None, None, 192)
# (None, None, None, 256)
# (None, None, None, 192)
# (None, None, None, 256)
# (None, None, None, 192)
# (None, None, None, 256)
# (None, None, None, 448)
# (None, None, None, 2080)
# (None, None, None, 2080)
# (None, None, None, 2080)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 224)
# (None, None, None, 224)
# (None, None, None, 224)
# (None, None, None, 192)
# (None, None, None, 256)
# (None, None, None, 192)
# (None, None, None, 256)
# (None, None, None, 192)
# (None, None, None, 256)
# (None, None, None, 448)
# (None, None, None, 2080)
# (None, None, None, 2080)
# (None, None, None, 2080)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 224)
# (None, None, None, 224)
# (None, None, None, 224)
# (None, None, None, 192)
# (None, None, None, 256)
# (None, None, None, 192)
# (None, None, None, 256)
# (None, None, None, 192)
# (None, None, None, 256)
# (None, None, None, 448)
# (None, None, None, 2080)
# (None, None, None, 2080)
# (None, None, None, 2080)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 192)
# (None, None, None, 224)
# (None, None, None, 224)
# (None, None, None, 224)
# (None, None, None, 192)
# (None, None, None, 256)
# (None, None, None, 192)
# (None, None, None, 256)
# (None, None, None, 192)
# (None, None, None, 256)
# (None, None, None, 448)
# (None, None, None, 2080)
# (None, None, None, 2080)
# (None, None, None, 1536)
# (None, None, None, 1536)
# (None, None, None, 1536)

# %%
bottleneck_features = {}
bottleneck_features['test'] = model_cropped.predict(test_tensors)

# %%
bottleneck_features['test'].shape[1:]
# Out:
# (5, 5, 1536)

# %%
bottleneck_features = {}
bottleneck_features['train'] = model_cropped.predict(train_tensors)
bottleneck_features['valid'] = model_cropped.predict(valid_tensors)
bottleneck_features['test'] = model_cropped.predict(test_tensors)

# %%
bottleneck_features['train'].shape[1:]
# Out:
# (5, 5, 1536)

# %%
dog_files_short = test_files[:100]

# %%
tensor = path_to_tensor(dog_files_short[1])
bottleneck = model_cropped.predict(irnv2_preproccess_input(tensor))

# %%
bottleneck.shape[1:]
# Out:
# (5, 5, 1536)

# %%
### TODO: Define your architecture.

# Adding dropouts as validation accuracy kept improving, but testing didn't 
doggo_model = Sequential()
doggo_model.add(GlobalAveragePooling2D(input_shape=bottleneck_features['train'].shape[1:]))
doggo_model.add(Dense(133))
doggo_model.add(Dropout(0.4))
doggo_model.add(Dense(133))
doggo_model.add(Dropout(0.4))
doggo_model.add(Dense(133, activation='softmax'))

doggo_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_1 ( (None, 1536)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 133)               204421
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 133)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 133)               17822
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 133)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 133)               17822
# =================================================================
# Total params: 240,065
# Trainable params: 240,065
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Compiling

# %%
### TODO: Compile the model.
doggo_model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %%
### TODO: specify the number of epochs that you would like to use to train the model.

epochs = 20

### Do NOT modify the code below this line.

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.doggo_model.hdf5', 
                               verbose=1, save_best_only=True)

doggo_model.fit(bottleneck_features['train'], train_targets, 
          validation_data=(bottleneck_features['valid'], valid_targets),
          epochs=epochs, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/20
# 6580/6680 [============================>.] - ETA: 0s - loss: 2.1928 - acc: 0.5302Epoch 00001: val_loss improved from inf to 0.80933, saving model to saved_models/weights.best.doggo_model.hdf5
# 6680/6680 [==============================] - 4s 567us/step - loss: 2.1849 - acc: 0.5313 - val_loss: 0.8093 - val_acc: 0.7629
# Epoch 2/20
# 6640/6680 [============================>.] - ETA: 0s - loss: 1.3387 - acc: 0.6941Epoch 00002: val_loss improved from 0.80933 to 0.62614, saving model to saved_models/weights.best.doggo_model.hdf5
# 6680/6680 [==============================] - 3s 383us/step - loss: 1.3383 - acc: 0.6940 - val_loss: 0.6261 - val_acc: 0.8204
# Epoch 3/20
# 6540/6680 [============================>.] - ETA: 0s - loss: 1.1431 - acc: 0.7287Epoch 00003: val_loss did not improve
# 6680/6680 [==============================] - 2s 358us/step - loss: 1.1482 - acc: 0.7280 - val_loss: 0.6672 - val_acc: 0.8108
# Epoch 4/20
# 6580/6680 [============================>.] - ETA: 0s - loss: 1.0625 - acc: 0.7413Epoch 00004: val_loss improved from 0.62614 to 0.61573, saving model to saved_models/weights.best.doggo_model.hdf5
# 6680/6680 [==============================] - 2s 355us/step - loss: 1.0604 - acc: 0.7418 - val_loss: 0.6157 - val_acc: 0.8204
# Epoch 5/20
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.9836 - acc: 0.7561Epoch 00005: val_loss improved from 0.61573 to 0.58806, saving model to saved_models/weights.best.doggo_model.hdf5
# 6680/6680 [==============================] - 2s 359us/step - loss: 0.9835 - acc: 0.7557 - val_loss: 0.5881 - val_acc: 0.8323
# Epoch 6/20
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.9289 - acc: 0.7702Epoch 00006: val_loss did not improve
# 6680/6680 [==============================] - 2s 357us/step - loss: 0.9344 - acc: 0.7687 - val_loss: 0.5886 - val_acc: 0.8299
# Epoch 7/20
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.8581 - acc: 0.7883Epoch 00007: val_loss did not improve
# 6680/6680 [==============================] - 2s 369us/step - loss: 0.8602 - acc: 0.7873 - val_loss: 0.6677 - val_acc: 0.8144
# Epoch 8/20
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.8175 - acc: 0.7873Epoch 00008: val_loss improved from 0.58806 to 0.56790, saving model to saved_models/weights.best.doggo_model.hdf5
# 6680/6680 [==============================] - 3s 380us/step - loss: 0.8159 - acc: 0.7879 - val_loss: 0.5679 - val_acc: 0.8323
# Epoch 9/20
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.7874 - acc: 0.7957Epoch 00009: val_loss did not improve
# 6680/6680 [==============================] - 2s 367us/step - loss: 0.7911 - acc: 0.7949 - val_loss: 0.5812 - val_acc: 0.8263
# Epoch 10/20
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.7336 - acc: 0.8060Epoch 00010: val_loss improved from 0.56790 to 0.56325, saving model to saved_models/weights.best.doggo_model.hdf5
# 6680/6680 [==============================] - 2s 366us/step - loss: 0.7355 - acc: 0.8057 - val_loss: 0.5633 - val_acc: 0.8443
# Epoch 11/20
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.7136 - acc: 0.8099Epoch 00011: val_loss improved from 0.56325 to 0.56294, saving model to saved_models/weights.best.doggo_model.hdf5
# 6680/6680 [==============================] - 2s 360us/step - loss: 0.7149 - acc: 0.8102 - val_loss: 0.5629 - val_acc: 0.8479
# Epoch 12/20
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.7050 - acc: 0.8126Epoch 00012: val_loss did not improve
# 6680/6680 [==============================] - 2s 355us/step - loss: 0.7041 - acc: 0.8129 - val_loss: 0.5690 - val_acc: 0.8395
# Epoch 13/20
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.6804 - acc: 0.8158Epoch 00013: val_loss improved from 0.56294 to 0.53068, saving model to saved_models/weights.best.doggo_model.hdf5
# 6680/6680 [==============================] - 2s 359us/step - loss: 0.6815 - acc: 0.8159 - val_loss: 0.5307 - val_acc: 0.8539
# Epoch 14/20
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.6595 - acc: 0.8206Epoch 00014: val_loss improved from 0.53068 to 0.48685, saving model to saved_models/weights.best.doggo_model.hdf5
# 6680/6680 [==============================] - 2s 360us/step - loss: 0.6608 - acc: 0.8202 - val_loss: 0.4868 - val_acc: 0.8491
# Epoch 15/20
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.6713 - acc: 0.8191Epoch 00015: val_loss did not improve
# 6680/6680 [==============================] - 2s 362us/step - loss: 0.6704 - acc: 0.8192 - val_loss: 0.4973 - val_acc: 0.8491
# Epoch 16/20
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.6398 - acc: 0.8239Epoch 00016: val_loss did not improve
# 6680/6680 [==============================] - 2s 356us/step - loss: 0.6394 - acc: 0.8244 - val_loss: 0.5647 - val_acc: 0.8299
# Epoch 17/20
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.6347 - acc: 0.8275Epoch 00017: val_loss did not improve
# 6680/6680 [==============================] - 2s 357us/step - loss: 0.6328 - acc: 0.8281 - val_loss: 0.5421 - val_acc: 0.8539
# Epoch 18/20
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.6129 - acc: 0.8257Epoch 00018: val_loss did not improve
# 6680/6680 [==============================] - 2s 367us/step - loss: 0.6137 - acc: 0.8256 - val_loss: 0.5879 - val_acc: 0.8383
# Epoch 19/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.6389 - acc: 0.8267Epoch 00019: val_loss did not improve
# 6680/6680 [==============================] - 2s 370us/step - loss: 0.6401 - acc: 0.8266 - val_loss: 0.5370 - val_acc: 0.8407
# Epoch 20/20
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.6169 - acc: 0.8292Epoch 00020: val_loss did not improve
# 6680/6680 [==============================] - 2s 355us/step - loss: 0.6190 - acc: 0.8283 - val_loss: 0.5599 - val_acc: 0.8407

# %%
### TODO: Load the model weights with the best validation loss.
doggo_model.load_weights('saved_models/weights.best.doggo_model.hdf5')

# %%
doggo_model = Sequential()
doggo_model.add(GlobalAveragePooling2D(input_shape=bottleneck_features['train'].shape[1:]))
doggo_model.add(Dense(133))
doggo_model.add(Dropout(0.4))
doggo_model.add(Dense(133))
doggo_model.add(Dropout(0.4))
doggo_model.add(Dense(133, activation='softmax'))
doggo_model.load_weights('saved_models/weights.best.doggo_model.hdf5')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-7090c784af6b> in <module>()
#       1 doggo_model = Sequential()
# ----> 2 doggo_model.add(GlobalAveragePooling2D(input_shape=bottleneck_features['train'].shape[1:]))
#       3 doggo_model.add(Dense(133))
#       4 doggo_model.add(Dropout(0.4))
#       5 doggo_model.add(Dense(133))
#
# NameError: name 'bottleneck_features' is not defined

# %% [markdown]
# ## Testing

# %%
### TODO: Calculate classification accuracy on the test dataset.
# get index of predicted dog breed for each image in test set
doggo_predictions = [np.argmax(doggo_model.predict(np.expand_dims(feature, axis=0))) for feature in bottleneck_features['test']]

# report test accuracy
test_accuracy = 100*np.sum(np.array(doggo_predictions)==np.argmax(test_targets, axis=1))/len(doggo_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 83.6124%

# %% [markdown]
# ## Putting it all together

# %%
def whos_that_doggo(imgpath):
    if dog_detector(imgpath):
        print("It's a doggo alright")
        tensor = path_to_tensor(imgpath)
        bottleneck = model_cropped.predict(irnv2_preproccess_input(tensor))
        prediction = doggo_model.predict(bottleneck)
        race = dog_names[np.argmax(prediction)]
        print(race)
        #print(doggo_model.predict(ResNet50_model_cropped.predict(paths_to_tensor(imgpath))))
    elif 1:#human_detector(imgpath):
        print('human')
    #if dog
        #what race
    #if human
        #sassy comment
        #what race resemples
    else:
        print('Heck fren, ur doin me a bamboozle')

# %%
pred = whos_that_doggo(dog_files_short[1])
# Out:
# It's a doggo alright
# Doberman_pinscher

# %%
dog_files_short = test_files[:100]
for i in range(100):
    whos_that_doggo(dog_files_short[i])
    print(dog_names[np.argmax(test_targets[i])])
#whos_that_doggo('images/Labrador_retriever_06449.jpg')
# Out:
# It's a doggo alright
# Dalmatian
# Dalmatian
# It's a doggo alright
# Doberman_pinscher
# Doberman_pinscher
# It's a doggo alright
# Papillon
# Papillon
# It's a doggo alright
# Bedlington_terrier
# Bedlington_terrier
# It's a doggo alright
# Flat-coated_retriever
# Flat-coated_retriever
# It's a doggo alright
# Belgian_sheepdog
# Belgian_sheepdog
# It's a doggo alright
# Canaan_dog
# Canaan_dog
# It's a doggo alright
# Clumber_spaniel
# Clumber_spaniel
# It's a doggo alright
# Lakeland_terrier
# Lakeland_terrier
# It's a doggo alright
# Chow_chow
# Chow_chow
# It's a doggo alright
# Afghan_hound
# Afghan_hound
# It's a doggo alright
# Bedlington_terrier
# Bedlington_terrier
# It's a doggo alright
# Glen_of_imaal_terrier
# Glen_of_imaal_terrier
# It's a doggo alright
# Silky_terrier
# Yorkshire_terrier
# It's a doggo alright
# German_shepherd_dog
# German_shepherd_dog
# It's a doggo alright
# Basenji
# Basenji
# It's a doggo alright
# Pomeranian
# Pomeranian
# It's a doggo alright
# Boston_terrier
# Boston_terrier
# It's a doggo alright
# Japanese_chin
# Japanese_chin
# It's a doggo alright
# Cairn_terrier
# Cairn_terrier
# It's a doggo alright
# Leonberger
# Leonberger
# It's a doggo alright
# French_bulldog
# French_bulldog
# It's a doggo alright
# Dachshund
# Dachshund
# It's a doggo alright
# Kuvasz
# Kuvasz
# It's a doggo alright
# Briard
# Briard
# It's a doggo alright
# Poodle
# Portuguese_water_dog
# It's a doggo alright
# Bedlington_terrier
# Bedlington_terrier
# It's a doggo alright
# Bedlington_terrier
# Bedlington_terrier
# It's a doggo alright
# Keeshond
# Keeshond
# It's a doggo alright
# Old_english_sheepdog
# Old_english_sheepdog
# It's a doggo alright
# Alaskan_malamute
# Alaskan_malamute
# It's a doggo alright
# Norwegian_elkhound
# Norwegian_elkhound
# It's a doggo alright
# Border_collie
# Border_collie
# It's a doggo alright
# Bernese_mountain_dog
# Bernese_mountain_dog
# It's a doggo alright
# Chow_chow
# Newfoundland
# It's a doggo alright
# Greater_swiss_mountain_dog
# Greater_swiss_mountain_dog
# It's a doggo alright
# Boykin_spaniel
# Boykin_spaniel
# It's a doggo alright
# Bull_terrier
# Bull_terrier
# It's a doggo alright
# Akita
# Akita
# It's a doggo alright
# Pembroke_welsh_corgi
# Pembroke_welsh_corgi
# It's a doggo alright
# Greyhound
# Greyhound
# It's a doggo alright
# Welsh_springer_spaniel
# Welsh_springer_spaniel
# It's a doggo alright
# Cairn_terrier
# Cairn_terrier
# It's a doggo alright
# Bloodhound
# Bloodhound
# It's a doggo alright
# English_cocker_spaniel
# English_cocker_spaniel
# It's a doggo alright
# Afghan_hound
# Afghan_hound
# It's a doggo alright
# Maltese
# Maltese
# It's a doggo alright
# Italian_greyhound
# Italian_greyhound
# It's a doggo alright
# Irish_water_spaniel
# Irish_water_spaniel
# It's a doggo alright
# American_staffordshire_terrier
# American_staffordshire_terrier
# It's a doggo alright
# Bouvier_des_flandres
# Bouvier_des_flandres
# It's a doggo alright
# Basenji
# Finnish_spitz
# It's a doggo alright
# Black_russian_terrier
# Bouvier_des_flandres
# It's a doggo alright
# Basenji
# Basenji
# It's a doggo alright
# Boykin_spaniel
# Boykin_spaniel
# It's a doggo alright
# Lowchen
# Petit_basset_griffon_vendeen
# It's a doggo alright
# Manchester_terrier
# Manchester_terrier
# It's a doggo alright
# Miniature_schnauzer
# Miniature_schnauzer
# It's a doggo alright
# Border_terrier
# Border_terrier
# It's a doggo alright
# Irish_terrier
# Lakeland_terrier
# It's a doggo alright
# Canaan_dog
# Australian_cattle_dog
# It's a doggo alright
# Mastiff
# Mastiff
# It's a doggo alright
# Boxer
# Boxer
# It's a doggo alright
# Labrador_retriever
# Labrador_retriever
# It's a doggo alright
# Lowchen
# Lowchen
# It's a doggo alright
# Bluetick_coonhound
# Bluetick_coonhound
# It's a doggo alright
# Yorkshire_terrier
# Yorkshire_terrier
# It's a doggo alright
# German_shorthaired_pointer
# Pointer
# It's a doggo alright
# Canaan_dog
# Canaan_dog
# It's a doggo alright
# Brussels_griffon
# Brussels_griffon
# It's a doggo alright
# Irish_water_spaniel
# Irish_water_spaniel
# It's a doggo alright
# Dandie_dinmont_terrier
# Dandie_dinmont_terrier
# It's a doggo alright
# Maltese
# Maltese
# It's a doggo alright
# Doberman_pinscher
# Doberman_pinscher
# It's a doggo alright
# Norwegian_elkhound
# German_shepherd_dog
# It's a doggo alright
# Cocker_spaniel
# English_cocker_spaniel
# It's a doggo alright
# Border_terrier
# Border_terrier
# It's a doggo alright
# Poodle
# Poodle
# It's a doggo alright
# Brussels_griffon
# Brussels_griffon
# It's a doggo alright
# Flat-coated_retriever
# Flat-coated_retriever
# It's a doggo alright
# Smooth_fox_terrier
# Smooth_fox_terrier
# It's a doggo alright
# Mastiff
# Mastiff
# It's a doggo alright
# Bulldog
# Bulldog
# human
# Havanese
# It's a doggo alright
# Kerry_blue_terrier
# Kerry_blue_terrier
# It's a doggo alright
# Irish_terrier
# Irish_terrier
# It's a doggo alright
# Entlebucher_mountain_dog
# Entlebucher_mountain_dog
# It's a doggo alright
# Cavalier_king_charles_spaniel
# Cavalier_king_charles_spaniel
# It's a doggo alright
# Pomeranian
# American_eskimo_dog
# It's a doggo alright
# Brittany
# Brittany
# It's a doggo alright
# Komondor
# Komondor
# It's a doggo alright
# Basset_hound
# Basset_hound
# It's a doggo alright
# Wirehaired_pointing_griffon
# Wirehaired_pointing_griffon
# It's a doggo alright
# German_pinscher
# German_pinscher
# It's a doggo alright
# Belgian_tervuren
# Belgian_tervuren
# It's a doggo alright
# Belgian_malinois
# Belgian_malinois
# It's a doggo alright
# Tibetan_mastiff
# Tibetan_mastiff
# It's a doggo alright
# Doberman_pinscher
# German_pinscher
# It's a doggo alright
# Boykin_spaniel
# Boykin_spaniel
# It's a doggo alright
# Norwegian_elkhound
# Norwegian_elkhound
